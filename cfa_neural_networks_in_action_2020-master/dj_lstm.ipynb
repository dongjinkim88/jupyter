# %% [markdown]
# # Neural Networks in Action for Time Series Forecasting
#
# ### Objective: Understand and implement CNNs and LSTMs by forecasting the Nifty500 returns
# ### Data Source : CEIC

# %% [markdown]
# # Installing pre-requisites

# %% [markdown]
# #### Installing Anaconda

# %% [markdown]
# You can install Anaconda from the following link
#
# https://www.anaconda.com/distribution/
#
#
# However, before installing Anaconda,do refer to the image attached below and remember to select ‘Add Anaconda to my PATH environment variable’ (ignore any warning against doing the same) while you’re installing Anaconda.
#
# <img src="conda_installation.png" alt="Drawing" style="width: 500px;"/>
#
# The whole installation process should not take more than 5-10mins
#
# ##### Installing key python libraries
#
# Having installed Anancoda with the aforementioned options selected. Run the following two lines in your command prompt.
# - You can find the command prompt by typing 'cmd' in your search bar as follows:
#
# <img src="cmd.png" alt="Drawing" style="width: 500px;"/>
#
# Once the command prompt is open,run the following two lines (starting with pip) in it:
#
# - pip install tensorflow==1.15.0
#
# - pip install keras==2.3.1

# %% [markdown]
# # Importing Basic Libraries

# %%
#make sure you have the correct versions installed
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.4.0
# 2.4.0

# %%
import random as rn
import numpy as np
import pandas as pd
import os
import glob
import datetime

# %% [markdown]
# # 1. Load the data

# %%
#changing the directory to where you have downloaded the data
#os.chdir('C:\\Users\\Cafral\\Desktop\\CAFRAL\\Intro MLTS\\cfa_data')

df = pd.read_csv('cfa_nn_data.csv')

# %%
df.drop(['Unnamed: 0'],inplace=True,axis=1) #removing unnecessary columns

#reformatting and sorting by date
df['date'] = pd.to_datetime(df['date']) #always format the date
df = df.sort_values(['date'])

# %% [markdown]
# # 2. Cleaning the Data

# %% [markdown]
# ### 2.1 Next, it is important to drop weekends as the Indian stock market does not normally trade on weekends.

# %%
#Removing weekends
df = df[(df['date'].dt.dayofweek != 5)&(df['date'].dt.dayofweek != 6)]

# %% [markdown]
# ### 2.2 Now, dealing with missing values: first , all the columns with more that 10% of missing values are dropped.

# %%
#dropping if ptage of missing values is greater than 10%
df = df.loc[:, df.isna().sum()/df.shape[0] <= 0.1]
df = df.dropna(axis=0,how='all',subset=df.columns[1:])
df.head()
# Out:
#         date  Bombay Stock Exchange: Index: 100  \
# 2 2000-01-03                            1636.49
# 3 2000-01-04                            1690.67
# 4 2000-01-05                            1643.14
# 5 2000-01-06                            1644.78
# 6 2000-01-07                            1606.46
#
#    Bombay Stock Exchange: Index: SENSEX  Bombay Stock Exchange: Index: 200  \
# 2                               5375.11                             635.04
# 3                               5491.01                             652.91
# 4                               5357.00                             636.89
# 5                               5421.53                             636.96
# 6                               5414.48                             620.91
#
#    Bombay Stock Exchange: Index: Dollex-200  \
# 2                                    243.17
# 3                                    249.89
# 4                                    243.65
# 5                                    243.68
# 6                                    237.59
#
#    Bombay Stock Exchange: Index: 500  \
# 2                            1920.08
# 3                            1972.29
# 4                            1922.87
# 5                            1923.36
# 6                            1871.82
#
#    Bombay Stock Exchange: Index: Information Technology  \
# 2                                            4260.20
# 3                                            4554.08
# 4                                            4342.29
# 5                                            4160.10
# 6                                            3828.79
#
#    Bombay Stock Exchange: Index: Capital Goods  \
# 2                                      1196.46
# 3                                      1179.47
# 4                                      1145.40
# 5                                      1174.28
# 6                                      1138.47
#
#    Bombay Stock Exchange: Index: Fast Moving Consumer Goods  \
# 2                                            1172.50
# 3                                            1138.74
# 4                                            1116.22
# 5                                            1168.77
# 6                                            1207.37
#
#    Bombay Stock Exchange: Index: Consumer Durables  ...  \
# 2                                          1526.33  ...
# 3                                          1517.65  ...
# 4                                          1470.10  ...
# 5                                          1531.15  ...
# 6                                          1497.40  ...
#
#    National Stock Exchange: Index: Nifty 500  \
# 2                                    1291.55
# 3                                    1335.45
# 4                                    1303.80
# 5                                    1306.60
# 6                                    1276.30
#
#    National Stock Exchange: PE Ratio: Nifty 50  \
# 2                                        25.91
# 3                                        26.67
# 4                                        25.97
# 5                                        26.32
# 6                                        26.25
#
#    National Stock Exchange: PB Ratio: Nifty 50  \
# 2                                         4.63
# 3                                         4.76
# 4                                         4.64
# 5                                         4.70
# 6                                         4.69
#
#    National Stock Exchange: Dividend Yield: Nifty 50  \
# 2                                               0.95
# 3                                               0.92
# 4                                               0.95
# 5                                               0.94
# 6                                               0.94
#
#    National Stock Exchange: Turnover: Value  \
# 2                                   17533.5
# 3                                   42680.2
# 4                                   71379.8
# 5                                   53708.6
# 6                                   32486.1
#
#    National Stock Exchange: Turnover: Volume  \
# 2                                     76.083
# 3                                    106.734
# 4                                    146.836
# 5                                    124.514
# 6                                    101.047
#
#    National Stock Exchange: Turnover: Trade: Advance  \
# 2                                             1020.0
# 3                                              464.0
# 4                                              387.0
# 5                                              631.0
# 6                                              317.0
#
#    National Stock Exchange: Turnover: Trade: Decline  \
# 2                                              142.0
# 3                                              747.0
# 4                                              790.0
# 5                                              511.0
# 6                                              795.0
#
#    National Stock Exchange: Trade  \
# 2                        267038.0
# 3                        445618.0
# 4                        651968.0
# 5                        529011.0
# 6                        372075.0
#
#    National Stock Exchange: Market Capitalization: Total
# 2                                          9121240.0
# 3                                          9369010.0
# 4                                          9186620.0
# 5                                          9221700.0
# 6                                          9022490.0
#
# [5 rows x 61 columns]

# %% [markdown]
# ### 2.3 Second, for the remaining columns with at most 10% missing observation, the missing values are fillied using linear interpolation.

# %%
#linear interpolation to deal with missing data
date = df['date']
df = df[df.columns[1:]].astype(float).interpolate(method ='linear',axis = 0,limit=30,
                                                              limit_direction ='forward')

#sort by date
df['date'] = date
df = df.sort_values(['date'])

# %% [markdown]
# # 3. Making the Data Stationary

# %% [markdown]
# #### 3.1  What is stationarity?
# - Stationarity is a property of time series data stating that the distributional properties (mean and standard deviation) of the data series has not changed across time.
#
#
# #### 3.2  Why is it important to have stationarity data?
# - For forecasting it is important that the data be stationary because in the absence of stationarity, one is asking the model to predict data that is nothing like anything it has seen before.
#
# #### 3.4 How do you test for stationarity?
# - A common test of stationarity is the Dickey-Fuller Test.
# - If the p-value associated with the Dickey-Fuller Test statistic is greater than 0.05, we state that the data is not stationary.

# %%
# Defining a function to test stationarity
#SOURCE:https://github.com/tklouie/PyData_LA_2018/blob/master/PyData_LA_2018_Tutorial.ipynb

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.tsa.stattools
from statsmodels.tsa.stattools import adfuller
import statsmodels.tsa.x13
from statsmodels.tsa.x13 import x13_arima_select_order, _find_x12
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.graphics.tsaplots as tsaplots

def test_stationarity(df, ts):

    # Determing rolling statistics
    rolmean = df[ts].rolling(window = 12, center = False).mean()
    rolstd = df[ts].rolling(window = 12, center = False).std()

    # Plot rolling statistics:
    orig = plt.plot(df[ts], color = 'blue',label = 'Original')
    mean = plt.plot(rolmean, color = 'red',label = 'Rolling Mean')
    std = plt.plot(rolstd, color = 'black', label = 'Rolling Std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation for %s' %(ts))
    plt.xticks(rotation = 45)
    plt.show(block = False)
    plt.close()

    # Perform Dickey-Fuller test:
    # Null Hypothesis (H_0): time series is not stationary
    # Alternate Hypothesis (H_1): time series is stationary
    print ('Results of Dickey-Fuller Test:')
    dftest = statsmodels.tsa.stattools.adfuller(df[ts], autolag='AIC') #add kpss
    
    dfoutput = pd.Series(dftest[0:4], index = ['Test Statistic','p-value', '# Lags Used','Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
#Applying the function to our Y variable: National Stock Exchange: Index: Nifty 500
test_stationarity(df, 'National Stock Exchange: Index: Nifty 500')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                    0.078353
# p-value                           0.964552
# # Lags Used                      13.000000
# Number of Observations Used    5244.000000
# Critical Value (1%)              -3.431598
# Critical Value (5%)              -2.862091
# Critical Value (10%)             -2.567063
# dtype: float64

# %% [markdown]
# - From the above results, we see that the p-value is  0.964552, leading to the conclusion that the Nifty500 Index series is not staionary.
# - It can be futher seen more clearly from the graph - the clear upward trend of the rolling mean and rolling standard deviation signals that Nifty500 is not stationary.
#
# ### 3.5  So what should one do when the data is not stationary? Make the data as stationary as possible
#
# The easiest was of making the data stationary is to claculate the first difference:
# - For level variables (like indices), the first difference in the percentage change vis-a-vis the previous time period
# - For percentage variables, its the value of the variable in the current time period subtracted from the value of the variables at the previous date.

# %%
#Defining a function to calculate percentage change
def percentChange(x,numLags):
    '''
    INPUTS:
    x: Column for which we want to calculate percent change
    numLags: The number of days from when the change needs to be calculated. 
            Example : If using daily data - numLags = 1 for daily change
                                            numLags = 30 for monthly change
                                            numLags = 365 for yearly change       
    OUTPUT:
    percentage change in variable
    '''
    y = (x - x.shift(numLags))/x.shift(numLags)
    return y

dataForMl = pd.DataFrame()
dataForMl['date'] = df['date']

#here, I only have level variables so I do not need separate my variables into level vs non-level variables
levelVars = df.columns[:-1]
for levelVar in levelVars:
    dataForMl[f'{levelVar}Ret'] = percentChange(df[levelVar],1)
    
dataForMl = dataForMl[1:] #ignoring the first row as it contains null values

# %% [markdown]
# Having calculated the percentage change for all our variables, let's check if our data is stationary now

# %%
test_stationarity(dataForMl, 'National Stock Exchange: Index: Nifty 500Ret')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.741829e+01
# p-value                        4.842084e-30
# # Lags Used                    1.300000e+01
# Number of Observations Used    5.243000e+03
# Critical Value (1%)           -3.431598e+00
# Critical Value (5%)           -2.862091e+00
# Critical Value (10%)          -2.567064e+00
# dtype: float64

# %% [markdown]
# - From the above graphs, we see that the percentage change in Nifty 500 Index (i.e. National Stock Exchange: Index: Nifty 500Ret) is stationary as the p-value is less that 0.05.
# - Again, for greater intuition look at the graph - the rolling mean and rolling standard deviation lines are along are almost flat meaning that they don't change in a statistically significant manner over time.
# - However, do note that taking the first difference does not necessarily have to make the data stationary.

# %% [markdown]
# # 4. Lagging the Data

# %% [markdown]
# - Next, because sequential/time series data is auto regressive in nature - i.e. the outcome today depends on the outcome yesterday and the outcome the day before yesterday and so on - we need to create lagged versions of each independent ariable.
#
# #### So how many lags of the independent variables do we want to include?
#
# - The maximum number of lags of the dependent variable to use can be decided from the Autocorrelation Function (ACF) and/or Partial Autocorrelation Function (PACF) plot or decided huristically based on domain specific cycles (ex:a business cycle,seasons etc).
# > ##### Autocorrelation function (ACF). At lag k, this is the correlation between series values that are k intervals apart.
# > ##### Partial autocorrelation function (PACF). At lag k, this is the correlation between series values that are k intervals apart, accounting for the values of the intervals between.
#
# - The maximum number of lags of other independent variables to include is rather arbitrary -  can be decided huristically based on domain specific cycles (ex:a business cycle,seasons etc).
#
# - The minimum number of lags to include depending on the forcasting horizon. If you want to forecast h steps ahead, you exclude the first h lags.

# %%
# We can make the acf and pacf plots using the statsmodels library in Python
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.graphics.tsaplots as tsaplots
from statsmodels.graphics.tsaplots import plot_acf

tsaplots.plot_acf(dataForMl['National Stock Exchange: Index: Nifty 500Ret'].astype(float),lags =25)
tsaplots.plot_pacf(dataForMl['National Stock Exchange: Index: Nifty 500Ret'].astype(float),lags =25)

# %% [markdown]
# - Both the ACF and PACF plots show high serial correlation at the first lag.

# %%
dataForMl.columns
# Out:
# Index(['date', 'Bombay Stock Exchange: Index: 100Ret',
#        'Bombay Stock Exchange: Index: SENSEXRet',
#        'Bombay Stock Exchange: Index: 200Ret',
#        'Bombay Stock Exchange: Index: Dollex-200Ret',
#        'Bombay Stock Exchange: Index: 500Ret',
#        'Bombay Stock Exchange: Index: Information TechnologyRet',
#        'Bombay Stock Exchange: Index: Capital GoodsRet',
#        'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRet',
#        'Bombay Stock Exchange: Index: Consumer DurablesRet',
#        'Bombay Stock Exchange: Index: Health CareRet',
#        'Bombay Stock Exchange: Index: AutoRet',
#        'Bombay Stock Exchange: Index: MetalRet',
#        'Bombay Stock Exchange: Index: Oil & GasRet',
#        'Bombay Stock Exchange: PE Ratio: Index: SENSEXRet',
#        'Bombay Stock Exchange: PE Ratio: Index: 100Ret',
#        'Bombay Stock Exchange: PE Ratio: Index: 200Ret',
#        'Bombay Stock Exchange: PB Ratio: Index: SENSEXRet',
#        'Bombay Stock Exchange: PB Ratio: Index: 100Ret',
#        'Bombay Stock Exchange: PB Ratio: Index: 200Ret',
#        'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRet',
#        'Bombay Stock Exchange: Dividend Yield: Index: 100Ret',
#        'Bombay Stock Exchange: Dividend Yield: Index: 200Ret',
#        'Bombay Stock Exchange: Scrips: Trade: TotalRet',
#        'Bombay Stock Exchange: Scrips: Trade: AdvanceRet',
#        'Bombay Stock Exchange: Scrips: Trade: DeclineRet',
#        'Bombay Stock Exchange: Scrips: Trade: UnchangedRet',
#        'Bombay Market Commodity Price: Gold: StandardRet',
#        'Bombay Market Commodity Price: Silver: .999Ret',
#        'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRet',
#        'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRet',
#        'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRet',
#        'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRet',
#        'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRet',
#        'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRet',
#        'RBI: Bank RateRet',
#        'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)Ret',
#        'SCB: Certificates of Deposits: Effective Interest Rate: LowRet',
#        'SCB: Certificates of Deposits: Effective Interest Rate: HighRet',
#        'Wholesale Debt Market: NSE: Securities: Trade: NumberRet',
#        'Wholesale Debt Market: NSE: Securities: Trade: ValueRet',
#        'Foreign Exchange Rate: RBI: Reference Rate: US DollarRet',
#        'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRet',
#        'Foreign Exchange Rate: RBI: Reference Rate: EuroRet',
#        'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRet',
#        'RBI: Cash Reserve RatioRet',
#        'National Stock Exchange: Index: Nifty 50Ret',
#        'National Stock Exchange: Index: Nifty Next 50Ret',
#        'National Stock Exchange: Index: Nifty ITRet',
#        'National Stock Exchange: Index: Nifty BankRet',
#        'National Stock Exchange: Index: Nifty50 USDRet',
#        'National Stock Exchange: Index: Nifty 500Ret',
#        'National Stock Exchange: PE Ratio: Nifty 50Ret',
#        'National Stock Exchange: PB Ratio: Nifty 50Ret',
#        'National Stock Exchange: Dividend Yield: Nifty 50Ret',
#        'National Stock Exchange: Turnover: ValueRet',
#        'National Stock Exchange: Turnover: VolumeRet',
#        'National Stock Exchange: Turnover: Trade: AdvanceRet',
#        'National Stock Exchange: Turnover: Trade: DeclineRet',
#        'National Stock Exchange: TradeRet',
#        'National Stock Exchange: Market Capitalization: TotalRet'],
#       dtype='object')

# %%
# Since we're going to forecast the one day ahead Nifty stock returns, the minimum lag considered by me is 1
minLagNum = 1

#lagging the vars :here i'm iginoring the ACF and PACF lag structure and deciding the maximum number of lags heuristically
maxLagNum = 10 #here I have chosen the maxLagNum arbitrarily. A better strategy is to look at the acf plot
dataForMl = dataForMl.sort_values(['date'])
for column in dataForMl.columns:
    for lag in range(minLagNum,maxLagNum+1):
        dataForMl[f'{column}Lag_{lag}'] = dataForMl[f'{column}'].shift(lag)
        

dataForMl.columns
# Out:
# Index(['date', 'Bombay Stock Exchange: Index: 100Ret',
#        'Bombay Stock Exchange: Index: SENSEXRet',
#        'Bombay Stock Exchange: Index: 200Ret',
#        'Bombay Stock Exchange: Index: Dollex-200Ret',
#        'Bombay Stock Exchange: Index: 500Ret',
#        'Bombay Stock Exchange: Index: Information TechnologyRet',
#        'Bombay Stock Exchange: Index: Capital GoodsRet',
#        'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRet',
#        'Bombay Stock Exchange: Index: Consumer DurablesRet',
#        ...
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_1',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_2',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_3',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_4',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_5',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_6',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_7',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_8',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_9',
#        'National Stock Exchange: Market Capitalization: TotalRetLag_10Lag_10'],
#       dtype='object', length=6771)

# %%
#sort by date
dataForMl = dataForMl.sort_values(['date'])

#removing columns if nan value in a column
dataForMl = dataForMl.dropna()

#specifying independent variables:including only lagged versions of variables and excluding date variables
final_vars = [col for col in dataForMl.columns if (col.find('Lag')!=-1) & (col.find('date')==-1)]

#specifying the dependent variable
dep_var = 'National Stock Exchange: Index: Nifty 500Ret'

#always make the dependent ariable the last column in the dataset
final_vars.append(dep_var)

#for later use
dataForMl_copy = dataForMl

#keeping only relevant 
dataForMl = dataForMl[final_vars]

# %%
final_vars
# Out:
# ['Bombay Stock Exchange: Index: 100RetLag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10',
#  'Bombay Stock Exchange: Index: 500RetLag_1',
#  'Bombay Stock Exchange: Index: 500RetLag_2',
#  'Bombay Stock Exchange: Index: 500RetLag_3',
#  'Bombay Stock Exchange: Index: 500RetLag_4',
#  'Bombay Stock Exchange: Index: 500RetLag_5',
#  'Bombay Stock Exchange: Index: 500RetLag_6',
#  'Bombay Stock Exchange: Index: 500RetLag_7',
#  'Bombay Stock Exchange: Index: 500RetLag_8',
#  'Bombay Stock Exchange: Index: 500RetLag_9',
#  'Bombay Stock Exchange: Index: 500RetLag_10',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_1',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_2',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_3',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_4',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_5',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_6',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_7',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_8',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_9',
#  'Bombay Stock Exchange: Index: Information TechnologyRetLag_10',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_1',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_2',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_3',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_4',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_5',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_6',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_7',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_8',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_9',
#  'Bombay Stock Exchange: Index: Capital GoodsRetLag_10',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_1',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_2',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_3',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_4',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_5',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_6',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_7',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_8',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_9',
#  'Bombay Stock Exchange: Index: Fast Moving Consumer GoodsRetLag_10',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_1',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_2',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_3',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_4',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_5',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_6',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_7',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_8',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_9',
#  'Bombay Stock Exchange: Index: Consumer DurablesRetLag_10',
#  'Bombay Stock Exchange: Index: Health CareRetLag_1',
#  'Bombay Stock Exchange: Index: Health CareRetLag_2',
#  'Bombay Stock Exchange: Index: Health CareRetLag_3',
#  'Bombay Stock Exchange: Index: Health CareRetLag_4',
#  'Bombay Stock Exchange: Index: Health CareRetLag_5',
#  'Bombay Stock Exchange: Index: Health CareRetLag_6',
#  'Bombay Stock Exchange: Index: Health CareRetLag_7',
#  'Bombay Stock Exchange: Index: Health CareRetLag_8',
#  'Bombay Stock Exchange: Index: Health CareRetLag_9',
#  'Bombay Stock Exchange: Index: Health CareRetLag_10',
#  'Bombay Stock Exchange: Index: AutoRetLag_1',
#  'Bombay Stock Exchange: Index: AutoRetLag_2',
#  'Bombay Stock Exchange: Index: AutoRetLag_3',
#  'Bombay Stock Exchange: Index: AutoRetLag_4',
#  'Bombay Stock Exchange: Index: AutoRetLag_5',
#  'Bombay Stock Exchange: Index: AutoRetLag_6',
#  'Bombay Stock Exchange: Index: AutoRetLag_7',
#  'Bombay Stock Exchange: Index: AutoRetLag_8',
#  'Bombay Stock Exchange: Index: AutoRetLag_9',
#  'Bombay Stock Exchange: Index: AutoRetLag_10',
#  'Bombay Stock Exchange: Index: MetalRetLag_1',
#  'Bombay Stock Exchange: Index: MetalRetLag_2',
#  'Bombay Stock Exchange: Index: MetalRetLag_3',
#  'Bombay Stock Exchange: Index: MetalRetLag_4',
#  'Bombay Stock Exchange: Index: MetalRetLag_5',
#  'Bombay Stock Exchange: Index: MetalRetLag_6',
#  'Bombay Stock Exchange: Index: MetalRetLag_7',
#  'Bombay Stock Exchange: Index: MetalRetLag_8',
#  'Bombay Stock Exchange: Index: MetalRetLag_9',
#  'Bombay Stock Exchange: Index: MetalRetLag_10',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_1',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_2',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_3',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_4',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_5',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_6',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_7',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_8',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_9',
#  'Bombay Stock Exchange: Index: Oil & GasRetLag_10',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_1',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_2',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_3',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_4',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_5',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_6',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_7',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_8',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_9',
#  'Bombay Stock Exchange: PE Ratio: Index: SENSEXRetLag_10',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_1',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_2',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_3',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_4',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_5',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_6',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_7',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_8',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_9',
#  'Bombay Stock Exchange: PE Ratio: Index: 100RetLag_10',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_1',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_2',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_3',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_4',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_5',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_6',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_7',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_8',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_9',
#  'Bombay Stock Exchange: PE Ratio: Index: 200RetLag_10',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_1',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_2',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_3',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_4',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_5',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_6',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_7',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_8',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_9',
#  'Bombay Stock Exchange: PB Ratio: Index: SENSEXRetLag_10',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_1',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_2',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_3',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_4',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_5',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_6',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_7',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_8',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_9',
#  'Bombay Stock Exchange: PB Ratio: Index: 100RetLag_10',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_1',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_2',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_3',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_4',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_5',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_6',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_7',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_8',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_9',
#  'Bombay Stock Exchange: PB Ratio: Index: 200RetLag_10',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_1',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_2',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_3',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_4',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_5',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_6',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_7',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_8',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_9',
#  'Bombay Stock Exchange: Dividend Yield: Index: SENSEXRetLag_10',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_1',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_2',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_3',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_4',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_5',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_6',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_7',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_8',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_9',
#  'Bombay Stock Exchange: Dividend Yield: Index: 100RetLag_10',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_1',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_2',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_3',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_4',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_5',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_6',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_7',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_8',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_9',
#  'Bombay Stock Exchange: Dividend Yield: Index: 200RetLag_10',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_1',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_2',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_3',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_4',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_5',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_6',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_7',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_8',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_9',
#  'Bombay Stock Exchange: Scrips: Trade: TotalRetLag_10',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_1',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_2',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_3',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_4',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_5',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_6',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_7',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_8',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_9',
#  'Bombay Stock Exchange: Scrips: Trade: AdvanceRetLag_10',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_1',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_2',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_3',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_4',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_5',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_6',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_7',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_8',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_9',
#  'Bombay Stock Exchange: Scrips: Trade: DeclineRetLag_10',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_1',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_2',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_3',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_4',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_5',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_6',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_7',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_8',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_9',
#  'Bombay Stock Exchange: Scrips: Trade: UnchangedRetLag_10',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_1',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_2',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_3',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_4',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_5',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_6',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_7',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_8',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_9',
#  'Bombay Market Commodity Price: Gold: StandardRetLag_10',
#  'Bombay Market Commodity Price: Silver: .999RetLag_1',
#  'Bombay Market Commodity Price: Silver: .999RetLag_2',
#  'Bombay Market Commodity Price: Silver: .999RetLag_3',
#  'Bombay Market Commodity Price: Silver: .999RetLag_4',
#  'Bombay Market Commodity Price: Silver: .999RetLag_5',
#  'Bombay Market Commodity Price: Silver: .999RetLag_6',
#  'Bombay Market Commodity Price: Silver: .999RetLag_7',
#  'Bombay Market Commodity Price: Silver: .999RetLag_8',
#  'Bombay Market Commodity Price: Silver: .999RetLag_9',
#  'Bombay Market Commodity Price: Silver: .999RetLag_10',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_1',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_2',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_3',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_4',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_5',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_6',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_7',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_8',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_9',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: LowRetLag_10',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_1',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_2',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_3',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_4',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_5',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_6',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_7',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_8',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_9',
#  'RBI: Companies: Commercial Paper: Effective Discount Rate: HighRetLag_10',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_1',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_2',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_3',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_4',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_5',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_6',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_7',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_8',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_9',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: LowRetLag_10',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_1',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_2',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_3',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_4',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_5',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_6',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_7',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_8',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_9',
#  'Deposit Rate: RBI: 5 Major Banks: Maturity > 1 Year: HighRetLag_10',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_1',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_2',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_3',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_4',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_5',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_6',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_7',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_8',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_9',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 1 MthRetLag_10',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_1',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_2',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_3',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_4',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_5',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_6',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_7',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_8',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_9',
#  'Foreign Exchange Rates: RBI: Interbank Forward Premia of USD: 3 MthsRetLag_10',
#  'RBI: Bank RateRetLag_1',
#  'RBI: Bank RateRetLag_2',
#  'RBI: Bank RateRetLag_3',
#  'RBI: Bank RateRetLag_4',
#  'RBI: Bank RateRetLag_5',
#  'RBI: Bank RateRetLag_6',
#  'RBI: Bank RateRetLag_7',
#  'RBI: Bank RateRetLag_8',
#  'RBI: Bank RateRetLag_9',
#  'RBI: Bank RateRetLag_10',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_1',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_2',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_3',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_4',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_5',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_6',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_7',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_8',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_9',
#  'Lending Rate: SBI: Benchmark Prime Lending Rate (BPLR)RetLag_10',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_1',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_2',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_3',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_4',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_5',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_6',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_7',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_8',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_9',
#  'SCB: Certificates of Deposits: Effective Interest Rate: LowRetLag_10',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_1',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_2',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_3',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_4',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_5',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_6',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_7',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_8',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_9',
#  'SCB: Certificates of Deposits: Effective Interest Rate: HighRetLag_10',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_1',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_2',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_3',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_4',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_5',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_6',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_7',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_8',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_9',
#  'Wholesale Debt Market: NSE: Securities: Trade: NumberRetLag_10',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_1',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_2',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_3',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_4',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_5',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_6',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_7',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_8',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_9',
#  'Wholesale Debt Market: NSE: Securities: Trade: ValueRetLag_10',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_1',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_2',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_3',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_4',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_5',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_6',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_7',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_8',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_9',
#  'Foreign Exchange Rate: RBI: Reference Rate: US DollarRetLag_10',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_1',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_2',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_3',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_4',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_5',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_6',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_7',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_8',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_9',
#  'Foreign Exchange Rate: RBI: Reference Rate: Pound SterlingRetLag_10',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_1',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_2',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_3',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_4',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_5',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_6',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_7',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_8',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_9',
#  'Foreign Exchange Rate: RBI: Reference Rate: EuroRetLag_10',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_1',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_2',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_3',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_4',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_5',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_6',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_7',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_8',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_9',
#  'Foreign Exchange Rate: RBI: Reference Rate: Japanese YenRetLag_10',
#  'RBI: Cash Reserve RatioRetLag_1',
#  'RBI: Cash Reserve RatioRetLag_2',
#  'RBI: Cash Reserve RatioRetLag_3',
#  'RBI: Cash Reserve RatioRetLag_4',
#  'RBI: Cash Reserve RatioRetLag_5',
#  'RBI: Cash Reserve RatioRetLag_6',
#  'RBI: Cash Reserve RatioRetLag_7',
#  'RBI: Cash Reserve RatioRetLag_8',
#  'RBI: Cash Reserve RatioRetLag_9',
#  'RBI: Cash Reserve RatioRetLag_10',
#  'National Stock Exchange: Index: Nifty 50RetLag_1',
#  'National Stock Exchange: Index: Nifty 50RetLag_2',
#  'National Stock Exchange: Index: Nifty 50RetLag_3',
#  'National Stock Exchange: Index: Nifty 50RetLag_4',
#  'National Stock Exchange: Index: Nifty 50RetLag_5',
#  'National Stock Exchange: Index: Nifty 50RetLag_6',
#  'National Stock Exchange: Index: Nifty 50RetLag_7',
#  'National Stock Exchange: Index: Nifty 50RetLag_8',
#  'National Stock Exchange: Index: Nifty 50RetLag_9',
#  'National Stock Exchange: Index: Nifty 50RetLag_10',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_1',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_2',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_3',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_4',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_5',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_6',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_7',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_8',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_9',
#  'National Stock Exchange: Index: Nifty Next 50RetLag_10',
#  'National Stock Exchange: Index: Nifty ITRetLag_1',
#  'National Stock Exchange: Index: Nifty ITRetLag_2',
#  'National Stock Exchange: Index: Nifty ITRetLag_3',
#  'National Stock Exchange: Index: Nifty ITRetLag_4',
#  'National Stock Exchange: Index: Nifty ITRetLag_5',
#  'National Stock Exchange: Index: Nifty ITRetLag_6',
#  'National Stock Exchange: Index: Nifty ITRetLag_7',
#  'National Stock Exchange: Index: Nifty ITRetLag_8',
#  'National Stock Exchange: Index: Nifty ITRetLag_9',
#  'National Stock Exchange: Index: Nifty ITRetLag_10',
#  'National Stock Exchange: Index: Nifty BankRetLag_1',
#  'National Stock Exchange: Index: Nifty BankRetLag_2',
#  'National Stock Exchange: Index: Nifty BankRetLag_3',
#  'National Stock Exchange: Index: Nifty BankRetLag_4',
#  'National Stock Exchange: Index: Nifty BankRetLag_5',
#  'National Stock Exchange: Index: Nifty BankRetLag_6',
#  'National Stock Exchange: Index: Nifty BankRetLag_7',
#  'National Stock Exchange: Index: Nifty BankRetLag_8',
#  'National Stock Exchange: Index: Nifty BankRetLag_9',
#  'National Stock Exchange: Index: Nifty BankRetLag_10',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_1',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_2',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_3',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_4',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_5',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_6',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_7',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_8',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_9',
#  'National Stock Exchange: Index: Nifty50 USDRetLag_10',
#  'National Stock Exchange: Index: Nifty 500RetLag_1',
#  'National Stock Exchange: Index: Nifty 500RetLag_2',
#  'National Stock Exchange: Index: Nifty 500RetLag_3',
#  'National Stock Exchange: Index: Nifty 500RetLag_4',
#  'National Stock Exchange: Index: Nifty 500RetLag_5',
#  'National Stock Exchange: Index: Nifty 500RetLag_6',
#  'National Stock Exchange: Index: Nifty 500RetLag_7',
#  'National Stock Exchange: Index: Nifty 500RetLag_8',
#  'National Stock Exchange: Index: Nifty 500RetLag_9',
#  'National Stock Exchange: Index: Nifty 500RetLag_10',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_1',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_2',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_3',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_4',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_5',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_6',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_7',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_8',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_9',
#  'National Stock Exchange: PE Ratio: Nifty 50RetLag_10',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_1',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_2',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_3',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_4',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_5',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_6',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_7',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_8',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_9',
#  'National Stock Exchange: PB Ratio: Nifty 50RetLag_10',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_1',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_2',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_3',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_4',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_5',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_6',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_7',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_8',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_9',
#  'National Stock Exchange: Dividend Yield: Nifty 50RetLag_10',
#  'National Stock Exchange: Turnover: ValueRetLag_1',
#  'National Stock Exchange: Turnover: ValueRetLag_2',
#  'National Stock Exchange: Turnover: ValueRetLag_3',
#  'National Stock Exchange: Turnover: ValueRetLag_4',
#  'National Stock Exchange: Turnover: ValueRetLag_5',
#  'National Stock Exchange: Turnover: ValueRetLag_6',
#  'National Stock Exchange: Turnover: ValueRetLag_7',
#  'National Stock Exchange: Turnover: ValueRetLag_8',
#  'National Stock Exchange: Turnover: ValueRetLag_9',
#  'National Stock Exchange: Turnover: ValueRetLag_10',
#  'National Stock Exchange: Turnover: VolumeRetLag_1',
#  'National Stock Exchange: Turnover: VolumeRetLag_2',
#  'National Stock Exchange: Turnover: VolumeRetLag_3',
#  'National Stock Exchange: Turnover: VolumeRetLag_4',
#  'National Stock Exchange: Turnover: VolumeRetLag_5',
#  'National Stock Exchange: Turnover: VolumeRetLag_6',
#  'National Stock Exchange: Turnover: VolumeRetLag_7',
#  'National Stock Exchange: Turnover: VolumeRetLag_8',
#  'National Stock Exchange: Turnover: VolumeRetLag_9',
#  'National Stock Exchange: Turnover: VolumeRetLag_10',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_1',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_2',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_3',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_4',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_5',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_6',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_7',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_8',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_9',
#  'National Stock Exchange: Turnover: Trade: AdvanceRetLag_10',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_1',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_2',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_3',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_4',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_5',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_6',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_7',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_8',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_9',
#  'National Stock Exchange: Turnover: Trade: DeclineRetLag_10',
#  'National Stock Exchange: TradeRetLag_1',
#  'National Stock Exchange: TradeRetLag_2',
#  'National Stock Exchange: TradeRetLag_3',
#  'National Stock Exchange: TradeRetLag_4',
#  'National Stock Exchange: TradeRetLag_5',
#  'National Stock Exchange: TradeRetLag_6',
#  'National Stock Exchange: TradeRetLag_7',
#  'National Stock Exchange: TradeRetLag_8',
#  'National Stock Exchange: TradeRetLag_9',
#  'National Stock Exchange: TradeRetLag_10',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_1',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_2',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_3',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_4',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_5',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_6',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_7',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_8',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_9',
#  'National Stock Exchange: Market Capitalization: TotalRetLag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_1Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_2Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_3Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_4Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_5Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_6Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_7Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_8Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_9Lag_10',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_1',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_2',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_3',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_4',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_5',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_6',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_7',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_8',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_9',
#  'Bombay Stock Exchange: Index: 100RetLag_10Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_1Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_2Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_3Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_4Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_5Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_6Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_7Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_8Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_9Lag_10',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_1',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_2',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_3',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_4',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_5',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_6',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_7',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_8',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_9',
#  'Bombay Stock Exchange: Index: SENSEXRetLag_10Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_1Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_2Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_3Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_4Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_5Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_6Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_7Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_8Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_9Lag_10',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_1',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_2',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_3',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_4',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_5',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_6',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_7',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_8',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_9',
#  'Bombay Stock Exchange: Index: 200RetLag_10Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_1Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_2Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_3Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_4Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_5Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_6Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_7Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_8Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_9Lag_10',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_1',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_2',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_3',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_4',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_5',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_6',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_7',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_8',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_9',
#  'Bombay Stock Exchange: Index: Dollex-200RetLag_10Lag_10',
#  ...]

# %% [markdown]
# # 5. Training, Validation and Testing
#
# - The objective of a machine learning methods is to predict the dependent variable as accurately as possible i.e. to minimize the predicted error (the difference between the actual value and predicted value).
#
# - To measure the predictive accuracy of a model, it is important that the forecast accuracy be measured out-of sample as the training accuracy can be made arbitrarily high through overfitting.
# - However, if we use the entire out-of-sample data for testing, we may overfit to the out-of-sample data (a phenomenon known as ‘data leakage’), resulting poor true generalizability.
# - To protect against ‘data leakage’, we split the out-of-sample data into two parts: validation data and testing data.
#
# - The validation  set allows the evaluation of the model on unseen data to select the best model architecture, while still holding out a subset of data for final evaluation after finding the best model.
#
# ### 5.1 The training, validation and testing data can be organized in many ways, namely:
# - cross validation (bootstrap sampling for cross sectional methods) : not suited for time series
# - fixed window (training, validation and testing periods demarcated by dates)
# - rolling window (shifting a window of fixed size ahead by one observation successively) / expanding window (increasing the window size by 1 successively).
#
# Given the time constraint, here I choosed a fixed window approach. The rolling or expanding window approach is highly reccomended if the time is available.

# %%
#breaking the data into train and test along time dim
test_percent = 0.10
no_test_obs =  int(np.round(test_percent*len(dataForMl)))
training = dataForMl[:-no_test_obs]
testing = dataForMl[-no_test_obs:]

#breaking the testing data into validation and out of sample data
validation_percent = 0.70
no_validation_obs = int(np.round(validation_percent*len(testing)))
validation = testing[:-no_validation_obs]
outOfSample = testing[-no_validation_obs:]

# %% [markdown]
# # 6. Rescaling Normalized Data

# %% [markdown]
# - Normailze the data in the training sample because machine learning methods are not scale invariant
# - Then we scale it to being between -1 and 1 as that is the appropriate scaling for data when being input into a Convolutional Neural Network (CNN) and Long Short Term Memory Network(LSTM).
# - Here this scaling for all the methods to make the prediction errors comparable.

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler(feature_range=(-1, 1))
trainMinmax = min_max_scaler.fit_transform(training.values) #fit and transform training data
valMinmax = min_max_scaler.transform(validation.values)
outSampleMinmax = min_max_scaler.transform(outOfSample.values)

# %% [markdown]
# #### Note that the rescaling parameters from the training sample are used to rescale the data in the validation and testing samples to ensure that the out-of-sample data does not have a look forward bias or 'data leakage'.

# %%
#breaking the data into independent variables (x) and dependent variables (y)

#training independent, dependent
trainMinmax_x,trainMinmax_y = trainMinmax[:,:-1],trainMinmax[:,-1] 

#validation independent, dependent
valMinmax_x,valMinmax_y = valMinmax[:,:-1],valMinmax[:,-1]

#out of sample testing independent, dependent
outSampleMinmax_x,outSampleMinmax_y = outSampleMinmax[:,:-1],outSampleMinmax[:,-1]

# %% [markdown]
# # 7.  Metric to be used to guage accuracy of forecasts
# - The most commonly used metric for guaging the accuracy of time series forecasts is the Mean Squared Error (MSE)
# - The higher the MSE, the worse is the predictive accuracy of the model.
# - Thus for each model,it is desired that the MSE be minimized.

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 8. Time Series Forecasting

# %%
os.chdir('C:\\Users\\Cafral\\Desktop\\CAFRAL\\Intro MLTS\\')

# %% [markdown]
# ### 8.1 So why is Linear Regression (OLS) not best suited for forecasting Time Series Data?
#
# <img src="ols_short_comings.PNG" alt="Drawing" style="width: 800px;"/>
#
# ###  8. 2 Potential Solution : Seasonal Autoregressive Integrated Moving Average (SARIMA)
#
# ### 8.2.1 What is SARIMA?
# - ARIMA models describe how each successive observation is related to the previous observation
# - The seasonal ARIMA (SARIMA) is capable of modelling the seasonal components in a univariate time series in addition to the autoregressive, moving average and trend components typically modelled by ARIMA.

# %%
#DEFINING SARIMA MODEL
import statsmodels.tsa.stattools
import statsmodels.api as sm

#(p,d,q) are determined using  Autocorrelation Function (ACF) , Partial Autocorrelation Functions (PACF) and tests for stationary.  
#How do we interpret ACF and PACF plots?

#p – Lag value where the PACF chart crosses the upper confidence interval for the first time.
#q – Lag value where the ACF chart crosses the upper confidence interval for the first time.

p= 1 #the trend autoregressive order.
d= 0 #the trend difference order.
q= 1 #the trend moving average order

P= 1 #the number of seasonal autoregressive terms.
D= 0 #the number of seasonal difference terms
Q= 1 #the number of seasonal moving average terms
M=1 #the number of time steps for a seasonal period 

myorder = (p,d,q)
myseasonalorder = (P,D,Q,M)
model = sm.tsa.statespace.SARIMAX(trainMinmax_y,
                                  order=myorder, 
                                  seasonal_order=myseasonalorder,
                                  trend='c')#,exog=trainMinmax_x 

#Training the model
model_fit = model.fit() 

# In case you want to add exgogenous variables
#exogNormal = normalizer.transform(testing.values)
#exogMinmax = min_max_scaler.transform(exogNormal)
#exogMinmax_x,exogMinmax_y = exogMinmax[:,:-1],exogMinmax[:,-1]

#Predicting
totat_preds = len(testing)#len(exogMinmax_y)
sarimaPred = model_fit.predict(start=1, end=totat_preds)#exog=exogMinmax_x

# %%
def plot_results(actual_y,predicted_y,method,date):
    mse = mean_squared_error(actual_y,predicted_y)
    
    plt.figure(figsize=(16,4))
    plt.plot(date,actual_y)
    plt.plot(date,predicted_y)
    plt.legend(['Actual','Predicted'])
    plt.title(f'{method} (MSE: {mse})')        
    plt.show()

# %%
plot_results(valMinmax_y,sarimaPred[:len(valMinmax_y)],'SARIMA Validation',range(len(valMinmax_y)))
plot_results(outSampleMinmax_y,sarimaPred[len(valMinmax_y):],'SARIMA Testing',range(len(outSampleMinmax_y)))

# %% [markdown]
# ![](sarima_vs_ols.PNG==100x20)

# %% [markdown]
# ### 8.2.2 SARIMA vs. OLS for Time Series Data
# <img src="sarima_vs_ols.PNG" alt="Drawing" style="width: 800px;"/>
#
#
# ### 8.2.3 Additional disadvantages of SARIMA : challenges of ARIMA models
# - Potential for error propagation
# - Backward looking: “they are generally poor at predicting turning points (unless the turning point represents a return to a long-run equilibrium)”.
# - Mean-reverting: As the number of steps forecasted ahead in the future increases , the forecast converges to the mean
# > But this is not a problem limited to ARIMA type models
#
# ### 8.3 Potential Solution : Deep Neural Networks (DNNs)
#
# #### 8.3.1 Why Only Focus on Deep Neural Networks?
# <img src="why_only_nn.PNG" alt="Drawing" style="width: 600px;"/>
#
# #### 8.3.2 What is a Neural Network?
#
# - In general, neural networks are composite functions which are universal function approximators.
#
# - Every neural network is broadly composed of three types of layers:
#
#   a. the input layer
#
#   b. the hidden layer / the computational layer
#
#   c. an output layer
#
# - Each of the 3 layers is comprised of multiple nodes and is connected to the subsequent layer through weights
#
# For some intution, let's model a linear regression with 3 independent variable as a neural network:
# <img src="lin_reg_as_nn.PNG" alt="Drawing" style="width: 800px;"/>
#
# #### 8.3.3 What is a deep neural network?
# - Neural Network with Multiple Hidden Layers
#
# #### 8.3.4 Where does the ‘learning’ in a neural network come from?
#
# <img src="dnn_learn_ffn.PNG" alt="Drawing" style="width: 800px;"/>
#
# #### 8.3.5 But Not All Neural Networks Are Suited for Time Series…
# - Look at linear regression as a neural network :
#
#     1) firstly,it treats the data cross sectionally. What does that mean?
#
#     2) no new features are created : does not find non-linearities in the data
#         Solution: Use a deep learning network -> creates non-linearities -> but problem: still treats data cross sectionally
# - Thus, a feed forward neural network cannot guage information from the spatial and sequential nature of time series data
# - Thus, it is not recommended that a fully connected feed forward neural network because it is dominated by more complex deep neural networks that can infer information from time series data
# - Here we consider two methods:
#
#     A) 1 Dimensional Convolutional Neural Networks (1D-CNNs)
#
#     B) Long Short Term Memory (LSTM) Networks
#
# #### 8.3.6 What makes CNNs and LSTMs different?
# - OLS and SARIMA depend on hand-selected independent variables supplied manually
#   - They do not use these independent variables to create new independent variables or 'features'
# - However, both CNNs and LSTMs can “learn an internal representation of the time series data and ideally achieve comparable performance to models fit on a version of the dataset with engineered features”
#     How?
#     - The input layer preserves the temporal structure of data
#     - The hidden layer/s use complex computational nodes: The different computational nodes used in a CNN vis-à-vis a LSTM network result in the two  type of networks processing the data differently.
#
# #### 8.3.7 What does it mean to preserve the temporal structure of the data?

# %%
from numpy import array

#split a multivariate sequence into samples that preserve the temporal structure of the data
#SOURCE:https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
n_steps_in =30 #number of observations from the past that we assume to be relevant across time for forecasting
n_steps_out = 1 #number of units ahead that we want to forecast into the future

#training sequence
trainSeq_x, trainSeq_y = split_sequences(trainMinmax, n_steps_in,n_steps_out)

#out of sample sequence
validationSeq_x, validationSeq_y= split_sequences(valMinmax, n_steps_in,n_steps_out)

#out of sample sequence
outSampleSeq_x, outSampleSeq_y= split_sequences(outSampleMinmax, n_steps_in,n_steps_out)

# %%
trainMinmax.shape #Output: (rows,columns)
# Out:
# (4713, 6601)

# %%
trainSeq_x.shape #Output: (number of samples,size of 'window' /timesteps,number of independent variables)
# Out:
# (4684, 30, 6600)

# %% [markdown]
# ### Important
#
# - The intitial weights of a neural network at assigned randomly and greatly affect how the network performs.
# - If you run your neural network - with the exactly same code and hyper-parameters - repeately, you will get different results
#  - Solution: Fix the random weights to the same weights every time the neural network is run

# %% [markdown]
# ### 8.4 Convolutional Neural Network
#
# - Convolutional neural networks (CNNs) can extract information from the temporal structure of the data by:
#        a) preserving the spatial/ temporal structure of the data in the input layer
#        b) using filters which look for patterns in spatially adjacent data
#        - For instance, one filter could finding pseaks, another could find troughs while another could find a linear trend
#        - The information extracted by the filters is known as a feature map
#        - Each additional feature results in a new feature map extracting a more complex feature
#        - For a time series dataset, a filter can only move along 1 dimension - time
#
# - The CNN layer may be followed by a sub-sampling layer which reduces the noise in the learned features (i.e. the feature maps)
#
# - The sub-sampling layer is followed by a regression layer

# %%
# Implementing a neural network in Keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, AveragePooling1D,MaxPooling1D
from tensorflow.keras.layers import Conv1D,AveragePooling1D,MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD, Nadam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l1,l2,l1_l2

# %%
############################# For Replicability : Always run this as one cell ##########################################
#SOURCE :
# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.
np.random.seed(42)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.

rn.seed(12345)

# Force TensorFlow to use single thread.
# Multiple threads are a potential source of non-reproducible results.
# For further details, see: https://stackoverflow.com/questions/42022950/

session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)

# The below tf.set_random_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/set_random_seed

tf.random.set_seed(1234)
#from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
###########################################################################################################################

#While training the neural network, it is important that we use the MSE error of the validation set to decide when to 
#stop training our network. If we use the MSE of the training set, we will not get good predictions in the test set due 
#to over fitting. However, unlike the error in the training set, the error in the validation set does not reduce with 
#every passing epoch. Sometimes, it increases for a while before it starts declining. The patience argument in Earlystop allows us 
#to decide how many times we want the validation error to keep increasing before we stop training the neural network.

EarlyStop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='auto',restore_best_weights=True)

epochs = 100000 #number of times the feed forward mechanism and back propagation are repeated 

bs = 100 #batch size for SGD :show what happens when batch size very small
lr =0 #learning rate: the degree to which the weights are updated by each batch of SGD

sgd = SGD(lr=lr) #type of optimizer - Alternative: ADAM, NADAM

X, y = split_sequences(trainMinmax, n_steps_in,n_steps_out)
n_features = X.shape[2]

np.random.seed(0)

model = Sequential() #initializing keras Sequential model

#convolutional layer starts
model.add(Conv1D(filters=5,#number of filters
                 kernel_size=2,#size of the filte racross time
                 strides=2, #number of rows that the filter moves ahead by
                 activation='linear',#transformation
                 input_shape=(n_steps_in, n_features))) #shape of 1 sample : preserves temporal structure
                #kernel_regularizer=l2(0.009),, bias_regularizer=l2(0.01)
#convolutional layer ends

model.add(MaxPooling1D(pool_size=1)) #sub-sampling layer - Alternative: AveragePooling1D

#model.add(BatchNormalization())
model.add(Dropout(0.1)) #reduces overfitting by dropping some weights randomly

#regression layer begins
model.add(Flatten())
model.add(Dense(1,#number of outputs
                activation='tanh',#transformation:other options include - ReLU,Linear,Sigmoid
                kernel_regularizer=l2(0.01))) 

model.compile(loss='mean_squared_error', optimizer='sgd') #specifies which optimizer and loss funtion to useto use 

#training the model
model.fit(trainSeq_x, trainSeq_y,
          batch_size=bs,
          epochs=epochs, 
          callbacks= [EarlyStop],
          verbose=2, 
          shuffle=False,#always set to false for time series data
          validation_data =(validationSeq_x, validationSeq_y))
                         
    
model.summary()
# Out:
# Epoch 1/100000
# 47/47 - 18s - loss: 1.3138 - val_loss: 1.3317
# Epoch 2/100000
# 47/47 - 5s - loss: 1.3342 - val_loss: 1.3313
# Epoch 3/100000
# 47/47 - 3s - loss: 1.3339 - val_loss: 1.3310
# Epoch 4/100000
# 47/47 - 3s - loss: 1.3335 - val_loss: 1.3306
# Epoch 5/100000
# 47/47 - 3s - loss: 1.3332 - val_loss: 1.3303
# Epoch 6/100000
# 47/47 - 3s - loss: 1.3328 - val_loss: 1.3300
# Epoch 7/100000
# 47/47 - 3s - loss: 1.3325 - val_loss: 1.3296
# Epoch 8/100000
# 47/47 - 3s - loss: 1.3322 - val_loss: 1.3293
# Epoch 9/100000
# 47/47 - 3s - loss: 1.3319 - val_loss: 1.3290
# Epoch 10/100000
# 47/47 - 3s - loss: 1.3316 - val_loss: 1.3287
# Epoch 11/100000
# 47/47 - 3s - loss: 1.3313 - val_loss: 1.3284
# Epoch 12/100000
# 47/47 - 3s - loss: 1.3310 - val_loss: 1.3281
# Epoch 13/100000
# 47/47 - 3s - loss: 1.3307 - val_loss: 1.3278
# Epoch 14/100000
# 47/47 - 3s - loss: 1.3304 - val_loss: 1.3275
# Epoch 15/100000
# 47/47 - 3s - loss: 1.3301 - val_loss: 1.3272
# Epoch 16/100000
# 47/47 - 3s - loss: 1.3298 - val_loss: 1.3270
# Epoch 17/100000
# 47/47 - 3s - loss: 1.3296 - val_loss: 1.3267
# Epoch 18/100000
# 47/47 - 5s - loss: 1.3293 - val_loss: 1.3264
# Epoch 19/100000
# 47/47 - 4s - loss: 1.3290 - val_loss: 1.3262
# Epoch 20/100000
# 47/47 - 3s - loss: 1.3288 - val_loss: 1.3259
# Epoch 21/100000
# 47/47 - 3s - loss: 1.3285 - val_loss: 1.3257
# Epoch 22/100000
# 47/47 - 3s - loss: 1.3283 - val_loss: 1.3254
# Epoch 23/100000
# 47/47 - 3s - loss: 1.3280 - val_loss: 1.3252
# Epoch 24/100000
# 47/47 - 3s - loss: 1.3278 - val_loss: 1.3250
# Epoch 25/100000
# 47/47 - 3s - loss: 1.3276 - val_loss: 1.3247
# Epoch 26/100000
# 47/47 - 3s - loss: 1.3273 - val_loss: 1.3245
# Epoch 27/100000
# 47/47 - 3s - loss: 1.3271 - val_loss: 1.3243
# Epoch 28/100000
# 47/47 - 3s - loss: 1.3269 - val_loss: 1.3241
# Epoch 29/100000
# 47/47 - 3s - loss: 1.3267 - val_loss: 1.3238
# Epoch 30/100000
# 47/47 - 3s - loss: 1.3265 - val_loss: 1.3236
# Epoch 31/100000
# 47/47 - 3s - loss: 1.3262 - val_loss: 1.3234
# Epoch 32/100000
# 47/47 - 3s - loss: 1.3260 - val_loss: 1.3232
# Epoch 33/100000
# 47/47 - 3s - loss: 1.3258 - val_loss: 1.3230
# Epoch 34/100000
# 47/47 - 3s - loss: 1.3256 - val_loss: 1.3228
# Epoch 35/100000
# 47/47 - 3s - loss: 1.3254 - val_loss: 1.3226
# Epoch 36/100000
# 47/47 - 3s - loss: 1.3253 - val_loss: 1.3225
# Epoch 37/100000
# 47/47 - 3s - loss: 1.3251 - val_loss: 1.3223
# Epoch 38/100000
# 47/47 - 3s - loss: 1.3249 - val_loss: 1.3221
# Epoch 39/100000
# 47/47 - 3s - loss: 1.3247 - val_loss: 1.3219
# Epoch 40/100000
# 47/47 - 3s - loss: 1.3245 - val_loss: 1.3217
# Epoch 41/100000
# 47/47 - 3s - loss: 1.3244 - val_loss: 1.3216
# Epoch 42/100000
# 47/47 - 3s - loss: 1.3242 - val_loss: 1.3214
# Epoch 43/100000
# 47/47 - 3s - loss: 1.3240 - val_loss: 1.3212
# Epoch 44/100000
# 47/47 - 3s - loss: 1.3239 - val_loss: 1.3211
# Epoch 45/100000
# 47/47 - 3s - loss: 1.3237 - val_loss: 1.3209
# Epoch 46/100000
# 47/47 - 3s - loss: 1.3235 - val_loss: 1.3208
# Epoch 47/100000
# 47/47 - 3s - loss: 1.3234 - val_loss: 1.3206
# Epoch 48/100000
# 47/47 - 3s - loss: 1.3232 - val_loss: 1.3204
# Epoch 49/100000
# 47/47 - 3s - loss: 1.3231 - val_loss: 1.3203
# Epoch 50/100000
# 47/47 - 3s - loss: 1.3229 - val_loss: 1.3202
# Epoch 51/100000
# 47/47 - 3s - loss: 1.3228 - val_loss: 1.3200
# Epoch 52/100000
# 47/47 - 3s - loss: 1.3227 - val_loss: 1.3199
# Epoch 53/100000
# 47/47 - 3s - loss: 1.3225 - val_loss: 1.3197
# Epoch 54/100000
# 47/47 - 3s - loss: 1.3224 - val_loss: 1.3196
# Epoch 55/100000
# 47/47 - 3s - loss: 1.3223 - val_loss: 1.3195
# Epoch 56/100000
# 47/47 - 3s - loss: 1.3221 - val_loss: 1.3193
# Epoch 57/100000
# 47/47 - 2s - loss: 1.3220 - val_loss: 1.3192
# Epoch 58/100000
# 47/47 - 2s - loss: 1.3219 - val_loss: 1.3191
# Epoch 59/100000
# 47/47 - 3s - loss: 1.3217 - val_loss: 1.3190
# Epoch 60/100000
# 47/47 - 2s - loss: 1.3216 - val_loss: 1.3188
# Epoch 61/100000
# 47/47 - 2s - loss: 1.3215 - val_loss: 1.3187
# Epoch 62/100000
# 47/47 - 2s - loss: 1.3214 - val_loss: 1.3186
# Epoch 63/100000
# 47/47 - 2s - loss: 1.3213 - val_loss: 1.3185
# Epoch 64/100000
# 47/47 - 3s - loss: 1.3212 - val_loss: 1.3184
# Epoch 65/100000
# 47/47 - 2s - loss: 1.3211 - val_loss: 1.3183
# Epoch 66/100000
# 47/47 - 2s - loss: 1.3209 - val_loss: 1.3182
# Epoch 67/100000
# 47/47 - 2s - loss: 1.3208 - val_loss: 1.3181
# Epoch 68/100000
# 47/47 - 3s - loss: 1.3207 - val_loss: 1.3180
# Epoch 69/100000
# 47/47 - 3s - loss: 1.3206 - val_loss: 1.3179
# Epoch 70/100000
# 47/47 - 2s - loss: 1.3205 - val_loss: 1.3178
# Epoch 71/100000
# 47/47 - 2s - loss: 1.3204 - val_loss: 1.3177
# Epoch 72/100000
# 47/47 - 3s - loss: 1.3203 - val_loss: 1.3176
# Epoch 73/100000
# 47/47 - 2s - loss: 1.3202 - val_loss: 1.3175
# Epoch 74/100000
# 47/47 - 2s - loss: 1.3201 - val_loss: 1.3174
# Epoch 75/100000
# 47/47 - 3s - loss: 1.3201 - val_loss: 1.3173
# Epoch 76/100000
# 47/47 - 3s - loss: 1.3200 - val_loss: 1.3172
# Epoch 77/100000
# 47/47 - 2s - loss: 1.3199 - val_loss: 1.3171
# Epoch 78/100000
# 47/47 - 3s - loss: 1.3198 - val_loss: 1.3170
# Epoch 79/100000
# 47/47 - 3s - loss: 1.3197 - val_loss: 1.3170
# Epoch 80/100000
# 47/47 - 3s - loss: 1.3196 - val_loss: 1.3169
# Epoch 81/100000
# 47/47 - 3s - loss: 1.3195 - val_loss: 1.3168
# Epoch 82/100000
# 47/47 - 3s - loss: 1.3195 - val_loss: 1.3167
# Epoch 83/100000
# 47/47 - 3s - loss: 1.3194 - val_loss: 1.3166
# Epoch 84/100000
# 47/47 - 2s - loss: 1.3193 - val_loss: 1.3166
# Epoch 85/100000
# 47/47 - 2s - loss: 1.3192 - val_loss: 1.3165
# Epoch 86/100000
# 47/47 - 2s - loss: 1.3192 - val_loss: 1.3164
# Epoch 87/100000
# 47/47 - 3s - loss: 1.3191 - val_loss: 1.3163
# Epoch 88/100000
# 47/47 - 2s - loss: 1.3190 - val_loss: 1.3163
# Epoch 89/100000
# 47/47 - 2s - loss: 1.3189 - val_loss: 1.3162
# Epoch 90/100000
# 47/47 - 2s - loss: 1.3189 - val_loss: 1.3161
# Epoch 91/100000
# 47/47 - 3s - loss: 1.3188 - val_loss: 1.3161
# Epoch 92/100000
# 47/47 - 3s - loss: 1.3187 - val_loss: 1.3160
# Epoch 93/100000
# 47/47 - 2s - loss: 1.3187 - val_loss: 1.3159
# Epoch 94/100000
# 47/47 - 2s - loss: 1.3186 - val_loss: 1.3159
# Epoch 95/100000
# 47/47 - 3s - loss: 1.3186 - val_loss: 1.3158
# Epoch 96/100000
# 47/47 - 2s - loss: 1.3185 - val_loss: 1.3157
# Epoch 97/100000
# 47/47 - 2s - loss: 1.3184 - val_loss: 1.3157
# Epoch 98/100000
# 47/47 - 3s - loss: 1.3184 - val_loss: 1.3156
# Epoch 99/100000
# 47/47 - 3s - loss: 1.3183 - val_loss: 1.3156
# Epoch 100/100000
# 47/47 - 3s - loss: 1.3183 - val_loss: 1.3155
# Epoch 101/100000
# 47/47 - 3s - loss: 1.3182 - val_loss: 1.3155
# Epoch 102/100000
# 47/47 - 3s - loss: 1.3181 - val_loss: 1.3154
# Epoch 103/100000
# 47/47 - 2s - loss: 1.3181 - val_loss: 1.3153
# Epoch 104/100000
# 47/47 - 2s - loss: 1.3180 - val_loss: 1.3153
# Epoch 105/100000
# 47/47 - 2s - loss: 1.3180 - val_loss: 1.3152
# Epoch 106/100000
# 47/47 - 3s - loss: 1.3179 - val_loss: 1.3152
# Epoch 107/100000
# 47/47 - 3s - loss: 1.3179 - val_loss: 1.3151
# Epoch 108/100000
# 47/47 - 3s - loss: 1.3178 - val_loss: 1.3151
# Epoch 109/100000
# 47/47 - 2s - loss: 1.3178 - val_loss: 1.3150
# Epoch 110/100000
# 47/47 - 2s - loss: 1.3177 - val_loss: 1.3150
# Epoch 111/100000
# 47/47 - 3s - loss: 1.3177 - val_loss: 1.3150
# Epoch 112/100000
# 47/47 - 2s - loss: 1.3176 - val_loss: 1.3149
# Epoch 113/100000
# 47/47 - 3s - loss: 1.3176 - val_loss: 1.3149
# Epoch 114/100000
# 47/47 - 3s - loss: 1.3176 - val_loss: 1.3148
# Epoch 115/100000
# 47/47 - 56s - loss: 1.3175 - val_loss: 1.3148
# Epoch 116/100000
# 47/47 - 8s - loss: 1.3175 - val_loss: 1.3147
# Epoch 117/100000
# 47/47 - 4s - loss: 1.3174 - val_loss: 1.3147
# Epoch 118/100000
# 47/47 - 3s - loss: 1.3174 - val_loss: 1.3147
# Epoch 119/100000
# 47/47 - 3s - loss: 1.3174 - val_loss: 1.3146
# Epoch 120/100000
# 47/47 - 3s - loss: 1.3173 - val_loss: 1.3146
# Epoch 121/100000
# 47/47 - 4s - loss: 1.3173 - val_loss: 1.3145
# Epoch 122/100000
# 47/47 - 3s - loss: 1.3172 - val_loss: 1.3145
# Epoch 123/100000
# 47/47 - 3s - loss: 1.3172 - val_loss: 1.3145
# Epoch 124/100000
# 47/47 - 3s - loss: 1.3172 - val_loss: 1.3144
# Epoch 125/100000
# 47/47 - 3s - loss: 1.3171 - val_loss: 1.3144
# Epoch 126/100000
# 47/47 - 3s - loss: 1.3171 - val_loss: 1.3144
# Epoch 127/100000
# 47/47 - 2s - loss: 1.3171 - val_loss: 1.3143
# Epoch 128/100000
# 47/47 - 3s - loss: 1.3170 - val_loss: 1.3143
# Epoch 129/100000
# 47/47 - 3s - loss: 1.3170 - val_loss: 1.3143
# Epoch 130/100000
# 47/47 - 3s - loss: 1.3170 - val_loss: 1.3142
# Epoch 131/100000
# 47/47 - 2s - loss: 1.3169 - val_loss: 1.3142
# Epoch 132/100000
# 47/47 - 3s - loss: 1.3169 - val_loss: 1.3142
# Epoch 133/100000
# 47/47 - 3s - loss: 1.3169 - val_loss: 1.3141
# Epoch 134/100000
# 47/47 - 3s - loss: 1.3168 - val_loss: 1.3141
# Epoch 135/100000
# 47/47 - 2s - loss: 1.3168 - val_loss: 1.3141
# Epoch 136/100000
# 47/47 - 2s - loss: 1.3168 - val_loss: 1.3140
# Epoch 137/100000
# 47/47 - 2s - loss: 1.3167 - val_loss: 1.3140
# Epoch 138/100000
# 47/47 - 2s - loss: 1.3167 - val_loss: 1.3140
# Epoch 139/100000
# 47/47 - 2s - loss: 1.3167 - val_loss: 1.3140
# Epoch 140/100000
# 47/47 - 3s - loss: 1.3167 - val_loss: 1.3139
# Epoch 141/100000
# 47/47 - 2s - loss: 1.3166 - val_loss: 1.3139
# Epoch 142/100000
# 47/47 - 2s - loss: 1.3166 - val_loss: 1.3139
# Epoch 143/100000
# 47/47 - 2s - loss: 1.3166 - val_loss: 1.3139
# Epoch 144/100000
# 47/47 - 3s - loss: 1.3166 - val_loss: 1.3138
# Epoch 145/100000
# 47/47 - 2s - loss: 1.3165 - val_loss: 1.3138
# Epoch 146/100000
# 47/47 - 2s - loss: 1.3165 - val_loss: 1.3138
# Epoch 147/100000
# 47/47 - 3s - loss: 1.3165 - val_loss: 1.3138
# Epoch 148/100000
# 47/47 - 3s - loss: 1.3165 - val_loss: 1.3137
# Epoch 149/100000
# 47/47 - 2s - loss: 1.3164 - val_loss: 1.3137
# Epoch 150/100000
# 47/47 - 3s - loss: 1.3164 - val_loss: 1.3137
# Epoch 151/100000
# 47/47 - 2s - loss: 1.3164 - val_loss: 1.3137
# Epoch 152/100000
# 47/47 - 3s - loss: 1.3164 - val_loss: 1.3137
# Epoch 153/100000
# 47/47 - 2s - loss: 1.3164 - val_loss: 1.3136
# Epoch 154/100000
# 47/47 - 2s - loss: 1.3163 - val_loss: 1.3136
# Epoch 155/100000
# 47/47 - 2s - loss: 1.3163 - val_loss: 1.3136
# Epoch 156/100000
# 47/47 - 3s - loss: 1.3163 - val_loss: 1.3136
# Epoch 157/100000
# 47/47 - 2s - loss: 1.3163 - val_loss: 1.3136
# Epoch 158/100000
# 47/47 - 2s - loss: 1.3163 - val_loss: 1.3135
# Epoch 159/100000
# 47/47 - 2s - loss: 1.3162 - val_loss: 1.3135
# Epoch 160/100000
# 47/47 - 2s - loss: 1.3162 - val_loss: 1.3135
# Epoch 161/100000
# 47/47 - 2s - loss: 1.3162 - val_loss: 1.3135
# Epoch 162/100000
# 47/47 - 2s - loss: 1.3162 - val_loss: 1.3135
# Epoch 163/100000
# 47/47 - 2s - loss: 1.3162 - val_loss: 1.3134
# Epoch 164/100000
# 47/47 - 3s - loss: 1.3161 - val_loss: 1.3134
# Epoch 165/100000
# 47/47 - 2s - loss: 1.3161 - val_loss: 1.3134
# Epoch 166/100000
# 47/47 - 2s - loss: 1.3161 - val_loss: 1.3134
# Epoch 167/100000
# 47/47 - 2s - loss: 1.3161 - val_loss: 1.3134
# Epoch 168/100000
# 47/47 - 3s - loss: 1.3161 - val_loss: 1.3134
# Epoch 169/100000
# 47/47 - 2s - loss: 1.3161 - val_loss: 1.3133
# Epoch 170/100000
# 47/47 - 2s - loss: 1.3160 - val_loss: 1.3133
# Epoch 171/100000
# 47/47 - 3s - loss: 1.3160 - val_loss: 1.3133
# Epoch 172/100000
# 47/47 - 3s - loss: 1.3160 - val_loss: 1.3133
# Epoch 173/100000
# 47/47 - 2s - loss: 1.3159 - val_loss: 1.3133
# Epoch 174/100000
# 47/47 - 2s - loss: 1.3158 - val_loss: 1.3130
# Epoch 175/100000
# 47/47 - 2s - loss: 0.8429 - val_loss: 0.7348
# Epoch 176/100000
# 47/47 - 3s - loss: 0.7462 - val_loss: 0.7348
# Epoch 177/100000
# 47/47 - 3s - loss: 0.7462 - val_loss: 0.7348
# Epoch 178/100000
# 47/47 - 3s - loss: 0.7462 - val_loss: 0.7347
# Epoch 179/100000
# 47/47 - 2s - loss: 0.7461 - val_loss: 0.7347
# Epoch 180/100000
# 47/47 - 2s - loss: 0.7461 - val_loss: 0.7347
# Epoch 181/100000
# 47/47 - 3s - loss: 0.7461 - val_loss: 0.7347
# Epoch 182/100000
# 47/47 - 2s - loss: 0.7461 - val_loss: 0.7347
# Epoch 183/100000
# 47/47 - 2s - loss: 0.7461 - val_loss: 0.7347
# Epoch 184/100000
# 47/47 - 3s - loss: 0.7460 - val_loss: 0.7346
# Epoch 185/100000
# 47/47 - 3709s - loss: 0.7460 - val_loss: 0.7346
# Epoch 186/100000
# 47/47 - 4s - loss: 0.7460 - val_loss: 0.7346
# Epoch 187/100000
# 47/47 - 3s - loss: 0.7460 - val_loss: 0.7346
# Epoch 188/100000
# 47/47 - 4s - loss: 0.7460 - val_loss: 0.7346
# Epoch 189/100000
# 47/47 - 3s - loss: 0.7460 - val_loss: 0.7346
# Epoch 190/100000
# 47/47 - 3s - loss: 0.7460 - val_loss: 0.7345
# Epoch 191/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7345
# Epoch 192/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7345
# Epoch 193/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7345
# Epoch 194/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7345
# Epoch 195/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7345
# Epoch 196/100000
# 47/47 - 2s - loss: 0.7459 - val_loss: 0.7345
# Epoch 197/100000
# 47/47 - 3s - loss: 0.7459 - val_loss: 0.7344
# Epoch 198/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 199/100000
# 47/47 - 3s - loss: 0.7458 - val_loss: 0.7344
# Epoch 200/100000
# 47/47 - 3s - loss: 0.7458 - val_loss: 0.7344
# Epoch 201/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 202/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 203/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 204/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 205/100000
# 47/47 - 2s - loss: 0.7458 - val_loss: 0.7344
# Epoch 206/100000
# 47/47 - 3s - loss: 0.7457 - val_loss: 0.7343
# Epoch 207/100000
# 47/47 - 3s - loss: 0.7457 - val_loss: 0.7343
# Epoch 208/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 209/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 210/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 211/100000
# 47/47 - 3s - loss: 0.7457 - val_loss: 0.7343
# Epoch 212/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 213/100000
# 47/47 - 3s - loss: 0.7457 - val_loss: 0.7343
# Epoch 214/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 215/100000
# 47/47 - 2s - loss: 0.7457 - val_loss: 0.7343
# Epoch 216/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 217/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 218/100000
# 47/47 - 2s - loss: 0.7456 - val_loss: 0.7342
# Epoch 219/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 220/100000
# 47/47 - 2s - loss: 0.7456 - val_loss: 0.7342
# Epoch 221/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 222/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 223/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 224/100000
# 47/47 - 2s - loss: 0.7456 - val_loss: 0.7342
# Epoch 225/100000
# 47/47 - 2s - loss: 0.7456 - val_loss: 0.7342
# Epoch 226/100000
# 47/47 - 3s - loss: 0.7456 - val_loss: 0.7342
# Epoch 227/100000
# 47/47 - 2s - loss: 0.7456 - val_loss: 0.7342
# Epoch 228/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 229/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 230/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7341
# Epoch 231/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7341
# Epoch 232/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7341
# Epoch 233/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 234/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 235/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 236/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7341
# Epoch 237/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 238/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 239/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7341
# Epoch 240/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 241/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 242/100000
# 47/47 - 2s - loss: 0.7455 - val_loss: 0.7341
# Epoch 243/100000
# 47/47 - 3s - loss: 0.7455 - val_loss: 0.7340
# Epoch 244/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 245/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 246/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 247/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 248/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 249/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 250/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 251/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 252/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 253/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 254/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 255/100000
# 47/47 - 3s - loss: 0.7454 - val_loss: 0.7340
# Epoch 256/100000
# 47/47 - 2s - loss: 0.7454 - val_loss: 0.7340
# Epoch 257/100000
# 47/47 - 3s - loss: 0.7453 - val_loss: 0.7339
# Epoch 258/100000
# 47/47 - 2s - loss: 0.7453 - val_loss: 0.7339
# Epoch 259/100000
# 47/47 - 2s - loss: 0.7450 - val_loss: 0.7323
# Epoch 260/100000
# 47/47 - 2s - loss: 1.2346 - val_loss: 1.3129
# Epoch 261/100000
# 47/47 - 2s - loss: 1.3156 - val_loss: 1.3129
# Epoch 262/100000
# 47/47 - 3s - loss: 1.3156 - val_loss: 1.3129
# Epoch 263/100000
# 47/47 - 3s - loss: 1.3156 - val_loss: 1.3129
# Epoch 264/100000
# 47/47 - 3s - loss: 1.3156 - val_loss: 1.3129
# Epoch 265/100000
# 47/47 - 2s - loss: 1.3156 - val_loss: 1.3128
# Epoch 266/100000
# 47/47 - 2s - loss: 1.3156 - val_loss: 1.3128
# Epoch 267/100000
# 47/47 - 2s - loss: 1.3156 - val_loss: 1.3128
# Epoch 268/100000
# 47/47 - 2s - loss: 1.3155 - val_loss: 1.3128
# Epoch 269/100000
# 47/47 - 2s - loss: 1.3155 - val_loss: 1.3128
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 15, 5)             66005
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 15, 5)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 5)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 75)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 76
# =================================================================
# Total params: 66,081
# Trainable params: 66,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation metrics 
cnnValPred = model.predict(validationSeq_x)

#testing prediction
cnnOutSamplePred = model.predict(outSampleSeq_x)
    
plot_results(validationSeq_y ,cnnValPred  ,'CNN Validation',range(len(validationSeq_y)))
plot_results(outSampleSeq_y ,cnnOutSamplePred  ,'CNN Testing',range(len(outSampleSeq_y)))

# %% [markdown]
# ### 8.5 Long Short Term Memory Network (LSTM)
# - A key shortcoming of CNNs for time series data is that they do not draw information from the sequential nature of independent data.
# - So, how does one build a neural network that can remember and extract information from a sequence? Long Short Term Memory (LSTM) Network.
#     - LSTM networks draw information from the sequential nature of the data because they have memory i.e. it remembers what it has seen
#     - LSTMs belong to a larger class of neural networks known as Recurrent Neural Networks, all of which have memory.
#     - Of many RNNs , LSTM are chosen here over a vanilla RNN as the former can learn from long sequences while the latter may not.
#
# #### 8.5.1 How does an LSTM network build short and long term memory?
# LSTMs build short and long term memories by revealing data to the hidden nodes in a sequential fashion.
#
# #### 8.5.2 How does sequential revealing allow an LSTM Node to Build Memory?
#
# Each LSTM node is comprised of LSTM cells.
#
# The long term and short term memory is updated in each LSTM cell upon being exposed to each subsequent element of the sequence , conditional on the output of each ‘gate’.
#
# #### 8.5.3 What is a gate?
#
# - Each “gate” is a neural network with a sigmoid/logistic activation function which determines how the memory updated by accepting as inputs:
#     a) the current elements X of the sequence
#
#     b) the outputs of the previous LSTM cell i.e. the long term memory and hidden memory from the previous member of the sequece
#
# - Each gate outputs a number between 0 (meaning no information is transferred ) and 1 (meaning all information is transferred).
#
# - In each LSTM cell, the following gates are used in the following order to build and update long term memory and short term memory:
#     - The Forget Gate / Remember Vector
#     - Candidate Gate
#     - Input Gate / Save Vector
#     - Output gate / Focus Vector
#
# - The updated working memory at the end of the sequence is the output of an LSTM node.
# - This working memory or hidden memory is the new internal representation of the data that is learnt by an LSTM network i.e. the working memory is the new feature used as an input in the regression layer.

# %%
#best
from tensorflow.keras.layers import LSTM

################################### Set for replicability ##################################################################
np.random.seed(42)
rn.seed(12345)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)
tf.random.set_seed(1234)
#from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
###########################################################################################################################


EarlyStop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='auto',restore_best_weights=True)
epochs = 100000
lr =0

sgd = SGD(lr=lr) #; adam = Adam(lr=lr) ;nadam = Nadam(lr=lr)
bs = 100

n_steps_in =30
n_steps_out = 1

#training sequence
trainSeq_x, trainSeq_y = split_sequences(trainMinmax, n_steps_in,n_steps_out)

#out of sample sequence
validationSeq_x, validationSeq_y= split_sequences(valMinmax, n_steps_in,n_steps_out)

#out of sample sequence
outSampleSeq_x, outSampleSeq_y= split_sequences(outSampleMinmax, n_steps_in,n_steps_out)

X_useless, y_useless = split_sequences(trainMinmax, n_steps_in,n_steps_out)
n_features = X_useless.shape[2]

np.random.seed(0); print(np.random.rand(4))

model = Sequential()
model.add(LSTM(300, #number of LSTM nodes
               input_shape=(n_steps_in, n_features),
               activation = 'tanh')) #ransformation:best to not use any other type of transformation
model.add(Dropout(0.1))
model.add(Dense(1,activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer='sgd')

#model
model.fit(trainSeq_x, trainSeq_y,batch_size=bs,epochs=epochs, callbacks= [EarlyStop] ,verbose=2, shuffle=False,
                         validation_data =(validationSeq_x, validationSeq_y))
# Out:
# [0.5488135  0.71518937 0.60276338 0.54488318]
# Epoch 1/100000
# 47/47 - 58s - loss: 1.2505 - val_loss: 0.0022
# Epoch 2/100000
# 47/47 - 44s - loss: 0.0129 - val_loss: 0.0022
# Epoch 3/100000
# 47/47 - 42s - loss: 0.0122 - val_loss: 0.0022
# Epoch 4/100000
# 47/47 - 170s - loss: 0.0123 - val_loss: 0.0022
# Epoch 5/100000
# 47/47 - 43s - loss: 0.0121 - val_loss: 0.0022
# Epoch 6/100000
# 47/47 - 44s - loss: 0.0116 - val_loss: 0.0022
# Epoch 7/100000
# 47/47 - 41s - loss: 0.0115 - val_loss: 0.0022
# Epoch 8/100000
# 47/47 - 40s - loss: 0.0113 - val_loss: 0.0022
# Epoch 9/100000
# 47/47 - 40s - loss: 0.0114 - val_loss: 0.0022
# Epoch 10/100000
# 47/47 - 41s - loss: 0.0112 - val_loss: 0.0022
# Epoch 11/100000
# 47/47 - 40s - loss: 0.0110 - val_loss: 0.0022
# Epoch 12/100000
# 47/47 - 41s - loss: 0.0108 - val_loss: 0.0022
# Epoch 13/100000
# 47/47 - 537s - loss: 0.0108 - val_loss: 0.0022
# Epoch 14/100000
# 47/47 - 43s - loss: 0.0108 - val_loss: 0.0022
# Epoch 15/100000
# 47/47 - 47s - loss: 0.0106 - val_loss: 0.0022
# Epoch 16/100000
# 47/47 - 41s - loss: 0.0105 - val_loss: 0.0022
# Epoch 17/100000
# 47/47 - 41s - loss: 0.0106 - val_loss: 0.0022
# Epoch 18/100000
# 47/47 - 41s - loss: 0.0105 - val_loss: 0.0022
# Epoch 19/100000
# 47/47 - 40s - loss: 0.0106 - val_loss: 0.0022
# Epoch 20/100000
# 47/47 - 41s - loss: 0.0105 - val_loss: 0.0022
# Epoch 21/100000
# 47/47 - 40s - loss: 0.0105 - val_loss: 0.0022
# Epoch 22/100000
# 47/47 - 41s - loss: 0.0104 - val_loss: 0.0022
# Epoch 23/100000
# 47/47 - 41s - loss: 0.0104 - val_loss: 0.0022
# Epoch 24/100000
# 47/47 - 42s - loss: 0.0103 - val_loss: 0.0022
# Epoch 25/100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-78fe779de381> in <module>
#      48 #model
#      49 model.fit(trainSeq_x, trainSeq_y,batch_size=bs,epochs=epochs, callbacks= [EarlyStop] ,verbose=2, shuffle=False,
# ---> 50                          validation_data =(validationSeq_x, validationSeq_y))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 300)               8281200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 8,281,501
# Trainable params: 8,281,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation metrics 
lstmValPred = model.predict(validationSeq_x)
#out of sample metrics
lstmOutSamplePred = model.predict(outSampleSeq_x)

plot_results(validationSeq_y ,lstmValPred  ,'LSTM Validation',range(len(validationSeq_y )))
plot_results(outSampleSeq_y ,lstmOutSamplePred  ,'LSTM Testing',range(len(outSampleSeq_y)))

# %% [markdown]
# # 9. Saving a Neural Network Model to use it later

# %%
#specify model name
model_name='lstm'
filename = f'{model_name}_model.h5'
model.save(filename)

# %%
# Create directory for storing output
dirName = f'C:\\Users\\Cafral\\Desktop\\CAFRAL\\Intro MLTS\\output' #change name to suitable folder here

try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")

####################################### change here onwards #######################################################

#change directory
os.chdir(dirName)

#specify model name
model_name='lstm'
filename = f'{model_name}_model.h5'
model.save(filename)
# Out:
# Directory  C:\Users\Cafral\Desktop\CAFRAL\Intro MLTS\output  Created

# %% [markdown]
# # 10. Calling a Saved Model

# %%
import tensorflow.keras as keras

#change directory
model_name='lstm' #change name of your model here
filename = f'{model_name}_model.h5' 
saved_model = keras.models.load_model(filename)


yhat = saved_model.predict(outSampleSeq_x) 
mse = mean_squared_error(outSampleSeq_y,cnnOutSamplePred)
print(mse)
# Out:
# 0.7340286587831281

# %% [markdown]
# # 11 Invert the Scaling

# %%
from numpy import concatenate
def invert_scaling(x_minmax,y_predicted,n_steps_in):
    reshaped_pred = y_predicted.reshape((y_predicted.shape[0],1))
    matrix = concatenate((x_minmax[n_steps_in-1:],reshaped_pred), axis=1)
    matrix_min_max_invert = min_max_scaler.inverse_transform(matrix)
    inv_pred = matrix_min_max_invert[:,-1]
    return inv_pred

# %%
inv_yhat = invert_scaling(outSampleMinmax_x,cnnOutSamplePred,n_steps_in)
plot_results(dataForMl_copy['National Stock Exchange: Index: Nifty 500Ret'][-(no_validation_obs-n_steps_in+1):].values,
             inv_yhat,
             'CNN Original Values',
             dataForMl_copy['date'][-(no_validation_obs-n_steps_in+1):])
# Out:
# /Users/djkim/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Summary
# <img src="summary_full.PNG" alt="Drawing" style="width: 800px;"/>
#
# <img src="hyperpara.PNG" alt="Drawing" style="width: 800px;"/>
#
# # Important Caveats
# - Machine learning methods, especially DNNs work best with large amounts of data

# %% [markdown]
# # References
#
# Tibshirani and Friedman (2017)
#
# Hastie, James , Tibshirani and Witten (n.d.)
#
# Goodfellow , Bengio and Courville (2016)
#
# https://machinelearningmastery.com/sarima-for-time-series-forecasting-in-python/
#
# https://github.com/tklouie/PyData_LA_2018/blob/master/PyData_LA_2018_Tutorial.ipynb
#
# https://datascience.stackexchange.com/questions/10615/number-of-parameters-in-an-lstm-model
#
# https://stackoverflow.com/questions/38080035/how-to-calculate-the-number-of-parameters-of-an-lstm-network
#
# https://stackoverflow.com/questions/50947079/keras-understanding-the-number-of-trainable-lstm-parameters
#
# https://datascience.stackexchange.com/questions/10615/number-of-parameters-in-an-lstm-model/27067#comment39272_27067
#
# https://www.coursera.org/lecture/ai/number-of-parameters-A3N10
#
# https://blog.acolyer.org/2019/02/25/understanding-hidden-memories-of-recurrent-neural-networks/
#
# https://machinelearningmastery.com/return-sequences-and-return-states-for-lstms-in-keras/
#
# http://blog.echen.me/2017/05/30/exploring-lstms/
#
# https://www.youtube.com/watch?v=lUhtcP2SUsg
